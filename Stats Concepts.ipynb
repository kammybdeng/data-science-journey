# %% [markdown]
# # Stats Concepts

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import skewnorm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Log

# %% [markdown]
# #### When to use log transform?

# %% [markdown]
# When we want to reduce skewness of the data.

# %% [markdown]
# Right skewed - data with outlier/tail on the right (ex. income)
#
# Left skewed - data with outlier/tail on the left (ex. good college GPA)

# %% [markdown]
# ### create a skewed dataset

# %%
np.random.seed(seed=42)
X = (np.random.randn(100,1))
print(X[:10])
# Out:
# [[ 0.49671415]
#  [-0.1382643 ]
#  [ 0.64768854]
#  [ 1.52302986]
#  [-0.23415337]
#  [-0.23413696]
#  [ 1.57921282]
#  [ 0.76743473]
#  [-0.46947439]
#  [ 0.54256004]]

# %%
r = skewnorm.rvs(a, size=100)

# %%
sns.distplot(r, color="y");

# %%
sns.distplot(r_2, color="y");

# %%
mean, var, skew, kurt
# Out:
# (array(-0.77406172), array(0.40082845), array(-0.78442676), array(0.63278475))

# %%
r_2 = r**2

# %%
np_log = np.log(r_2)

# %%
sns.distplot(np_log, color="y");

# %%
np.var(np_log)
# Out:
# 5.976510190579647

# %%
np.var(r_2)
# Out:
# 1.118270894902346
